# %%
dico=open("liste_francais.txt","r").read().split() # liste des mots

#print(dico[:100])

import random




#--------------------- Définition ----------------------#

mot=random.choice(dico) # mot donné par l'odinateur pris dans la liste de mot

nbreL=len(mot)
nbreLettreTrv=int(len(mot)-1) # nombre de lettre à trouver dans le mot, -1 car la première lettre est déjà donné

underscore=" _ "
UnderS=[underscore]*nbreLettreTrv


motATRV=[mot[0],UnderS] # mot du départ à trouver 

occurrence=0

erreur=0
erreurmax=11
taille=['_']*(len(mot))


del(taille[0])     # la fontcion del je l'ai trouvé sur : https://fr.moonbooks.org/Articles/Comment-supprimer-une-élément-dune-liste-avec-python/
#--------------------- Définition ----------------------#

#---------------------- Affichage ----------------------#

print("Les règles du jeu de ce pendu sont très simples:\n\n1. L'odinateur va donner un mot au hasard, et vous allez devoir deviner toutes les lettres ce mot !\n2. Vous allez devoir entrer une lettre, si elle fait partie du mot alors elle remplacera le _ correspondant, dans le cas contraire le dessin d’un pendu se met à apparaître.\n3. Attention:\n             -Il ne faudra pas re entrez une lettre qui a déjà été saisis et qui est fausse, parce que cela vous ajoutera juste une étape de plus au dessin du pendu donc moins de chance de trouver le mot.\n             - La première lettre du mot n'est pas considérer comme une lettre déjà saisis il faudra alors la saisir si vous le voulez, mais c'est un risque à prendre car si elle ne fait pas partie du mot, alors cette action sera comptée comme fausse et donc cela va vous enlever le droit à une erreur\n             - L'orthographe, les mots dans cette liste ne sont que des mots en miniscule veuillez ne saisir que des lettres miniscules; les lettres avec des accents etc... sont qualifiées comme une lettre (par exemples é, et è sont considérées comme deux lettres distinctes). Exemples:é,è,ê,ë,à,ï,ô,ç, etc...")# Regles du jeu

print("\n",mot)

print("\nLe nombre de lettres à trouver dans le mot est de",nbreLettreTrv)

print(motATRV)
#---------------------- Affichage ----------------------#
#--------------------- Boucle ---------------------#


while not erreur==11:
    l=input("Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : ")
    if l in mot:
        
        for i in range (len(taille)):
            if l == mot[i]:
                taille[i-1]=l
                print(mot[0],taille)
                
    elif not l in mot:
        erreurmax-=1
        print(f"Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : {erreurmax} erreurs")
        erreur+=1
    
        if erreur == 1:
            print("---------")
        if erreur == 2:
            print(" || \n || \n || \n || \n || \n---------")
        if erreur == 3:
            print(" || / \n ||/ \n || \n || \n || \n---------")
        if erreur == 4:
            print(" ----------- \n || / \n ||/ \n || \n || \n || \n---------")
        if erreur == 5:
            print(" ----------|- \n || /      |  \n ||/ \n || \n || \n || \n---------")
        if erreur == 6:
            print(" ----------|- \n || /      |  \n ||/       o  \n || \n || \n || \n---------")
        if erreur == 7:
            print(" ----------|- \n || /      |  \n ||/       o  \n ||        | \n || \n || \n---------")
        if erreur == 8:
            print(" ----------|- \n || /      |  \n ||/       o  \n ||       /| \n || \n || \n---------")
        if erreur == 9:
            print(" ----------|- \n || /      |  \n ||/       o  \n ||       /|\ \n || \n || \n---------")
        if erreur == 10:
            print(" ----------|- \n || /      |  \n ||/       o  \n ||       /|\ \n ||       / \n || \n---------")
       
                

print("vous avez perdu, le pendu est fini :\n  ----------|- \n || /      |  \n ||/       o  \n ||       /|\ \n ||       / \ \n || \n---------")
# Out:
# Les règles du jeu de ce pendu sont très simples:
#
# 1. L'odinateur va donner un mot au hasard, et vous allez devoir deviner toutes les lettres ce mot !
# 2. Vous allez devoir entrer une lettre, si elle fait partie du mot alors elle remplacera le _ correspondant, dans le cas contraire le dessin d’un pendu se met à apparaître.
# 3. Attention:
#              -Il ne faudra pas re entrez une lettre qui a déjà été saisis et qui est fausse, parce que cela vous ajoutera juste une étape de plus au dessin du pendu donc moins de chance de trouver le mot.
#              - La première lettre du mot n'est pas considérer comme une lettre déjà saisis il faudra alors la saisir si vous le voulez, mais c'est un risque à prendre car si elle ne fait pas partie du mot, alors cette action sera comptée comme fausse et donc cela va vous enlever le droit à une erreur
#              - L'orthographe, les mots dans cette liste ne sont que des mots en miniscule veuillez ne saisir que des lettres miniscules; les lettres avec des accents etc... sont qualifiées comme une lettre (par exemples é, et è sont considérées comme deux lettres distinctes). Exemples:é,è,ê,ë,à,ï,ô,ç, etc...
#
#  édenté
#
# Le nombre de lettres à trouver dans le mot est de 5
# ['é', [' _ ', ' _ ', ' _ ', ' _ ', ' _ ']]
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : z
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 10 erreurs
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : f
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 9 erreurs
#  ||
#  ||
#  ||
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : g
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 8 erreurs
#  || /
#  ||/
#  ||
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : d
# é ['d', '_', '_', '_', '_']
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : g
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 7 erreurs
#  -----------
#  || /
#  ||/
#  ||
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : n
# é ['d', '_', 'n', '_', '_']
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : s
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 6 erreurs
#  ----------|-
#  || /      |
#  ||/
#  ||
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : r
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 5 erreurs
#  ----------|-
#  || /      |
#  ||/       o
#  ||
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : g
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 4 erreurs
#  ----------|-
#  || /      |
#  ||/       o
#  ||        |
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : h
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 3 erreurs
#  ----------|-
#  || /      |
#  ||/       o
#  ||       /|
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : k
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 2 erreurs
#  ----------|-
#  || /      |
#  ||/       o
#  ||       /|\
#  ||
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : l
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 1 erreurs
#  ----------|-
#  || /      |
#  ||/       o
#  ||       /|\
#  ||       /
#  ||
# ---------
# Quelle lettre pensez vous qu'il y a dans le mot donné par l'ordinateur ? : l
# Cette lettre ne fait pas parti du mot à trouver, il ne vous reste que le droit a : 0 erreurs
# vous avez perdu, le pendu est fini :
#   ----------|-
#  || /      |
#  ||/       o
#  ||       /|\
#  ||       / \
#  ||
# ---------

# %%
 #elif erreur == 3:
        #print("   || /        
                  ||/         
                  ||        
                  ||         
                  ||           
                ---------")
    #elif erreur == 4:
        #print("   ----------- 
                  || /        
                  ||/        
                  ||       
                  ||         
                  ||           
                ---------")
    #elif erreur == 5:
        #print("   ----------|- 
                  || /      |  
                  ||/         
                  ||       
                  ||         
                  ||           
                ---------")
    #elif erreur == 6:
        #print("   ----------|- 
                  || /      |  
                  ||/       o 
                  ||       
                  ||         
                  ||           
                ---------")
                 #elif erreur == 7:
        #print("   ----------|- 
                  || /      |  
                  ||/       o 
                  ||        |     
                  ||         
                  ||           
                ---------")
    #elif erreur == 8:
        #print("   ----------|- 
                  || /      |  
                  ||/       o 
                  ||       /|     
                  ||         
                  ||           
                ---------")
    #elif erreur == 9:
        #print("   ----------|- 
                  || /      |  
                  ||/       o 
                  ||       /|\    
                  ||         
                  ||           
                ---------")
    #elif erreur == 10:
        #print("   ----------|- 
                  || /      |  
                  ||/       o 
                  ||       /|\    
                  ||       /
                  ||           
                ---------")


#print("vous avez perdu, le pendu est fini : ("----------|- 
                                              || /      |  
                                              ||/       o 
                                              ||       /|\    
                                              ||       / \
                                              ||           
                                            ---------")

# %%
  ----------|- 
  || /      |  
  ||/       o  
  ||       /|\ 
  ||       / \  
  ||           
---------
